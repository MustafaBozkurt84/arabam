# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 1.8 MB/s eta 0:00:01
# Collecting soupsieve>1.2; python_version >= "3.0"
#   Downloading soupsieve-2.1-py3-none-any.whl (32 kB)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=4d2d99d4d3e4cf33b95a7242d7b44c4004eaa2f6b3ec3743b69ced4b3ba13af0
#   Stored in directory: /home/train/.cache/pip/wheels/19/f5/6d/a97dd4f22376d4472d5f4c76c7646876052ff3166b3cf71050
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 soupsieve-2.1
# WARNING: You are using pip version 20.2.2; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/train/venvspark/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.6.2-cp36-cp36m-manylinux1_x86_64.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 3.4 MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.6.2
# WARNING: You are using pip version 20.2.2; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/train/venvspark/bin/python -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def Convert(a):
    it = iter(a)
    res_dct = dict(zip(it, it))
    return res_dct

# %%
df1=pd.DataFrame(columns=['İlan No:', 'İlan Tarihi:', 'Marka:', 'Seri:', 'Model:', 'Yıl:',
       'Yakıt Tipi:', 'Vites Tipi:', 'Motor Hacmi:', 'Motor Gücü:',
       'Kilometre:', 'Boya-değişen:', 'Takasa Uygun:', 'Kimden:'])

# %%
for page in range(1,50):
  url="https://www.arabam.com/ikinci-el/otomobil?page="+str(page)
  print(page,end=' ')
  r=requests.get(url)
  soup=BeautifulSoup(r.content,'html.parser')
  table=soup.find("table",attrs={"class":"table listing-table w100 border-grey2"})
  cars=table.find_all("a",attrs={"class":"listing-text-new word-break val-middle color-black2018"})
  for car in cars:
     
    car_Link=car.get("href")
    car_Link="https://www.arabam.com/"+car_Link
    
    #car_r=requests.get(car_Link)
    soup = BeautifulSoup(requests.get(car_Link).content, 'html.parser')
    table1=soup.find_all("span",attrs={"class":"bli-particle"})
    att=[]
    
    for i in table1:
        att.append(i.text)
    data=Convert(att)
    df=pd.DataFrame.from_dict(data, orient="index").T
    
    df1=pd.concat([df1,df],ignore_index=True,join="outer")
df1
# Out:
# 1
#         İlan No:        İlan Tarihi:               Marka:         Seri:  \
# 0    16223472      18 Aralık 2020                 Fiat          Egea
# 1    16223479      18 Aralık 2020              Peugeot           RCZ
# 2    16223090      18 Aralık 2020      Mercedes - Benz             C
# 3    16223085      18 Aralık 2020                 Fiat         Albea
# 4    16218068      18 Aralık 2020                 Audi            A6
# 5    16203050      18 Aralık 2020           Volkswagen          Polo
# 6    16164071      18 Aralık 2020           Volkswagen        Passat
# 7    16164066      18 Aralık 2020           Volkswagen          Golf
# 8    16222890      18 Aralık 2020           Volkswagen          Golf
# 9    16149981      18 Aralık 2020                 Ford        Fiesta
# 10   16033480      18 Aralık 2020                 Fiat          Egea
# 11   16221782      18 Aralık 2020              Renault          Clio
# 12   15953764      18 Aralık 2020                 Opel         Astra
# 13   16221577      18 Aralık 2020                  BMW      5 Serisi
# 14   16221561      18 Aralık 2020              Renault          Clio
# 15   16221516      18 Aralık 2020                Tofaş         Doğan
# 16   15963712      18 Aralık 2020           Volkswagen          Polo
# 17   15559377      18 Aralık 2020                 Opel         Astra
# 18   16151670      18 Aralık 2020                Honda         Civic
# 19   16151669      18 Aralık 2020      Mercedes - Benz             C
#
#                                  Model:      Yıl:       Yakıt Tipi:  \
# 0                 1.3 Multijet Urban      2017             Dizel
# 1                   1.6 THP Yearling      2011            Benzin
# 2                C 200 d BlueTEC AMG      2016             Dizel
# 3     Sole 1.3 Multijet Dynamic Plus      2010             Dizel
# 4                   A6 Sedan 2.0 TDI      2012             Dizel
# 5                  1.4 TDi Trendline      2015             Dizel
# 6                   2.0 TDi Highline      2009             Dizel
# 7                      1.6 Primeline      2009      LPG & Benzin
# 8                1.6 TDi Comfortline      2011             Dizel
# 9                 1.6 Ti-VCT Trend X      2017      LPG & Benzin
# 10                 1.3 Multijet Easy      2016             Dizel
# 11                     1.5 dCi Touch      2016             Dizel
# 12                         1.6 Enjoy      2012      LPG & Benzin
# 13                      520i M Sport      2014            Benzin
# 14                     1.5 dCi Touch      2017             Dizel
# 15                               SLX      1995      LPG & Benzin
# 16               1.4 TDi Comfortline      2017             Dizel
# 17               1.6 CDTI Excellence      2016             Dizel
# 18           1.6 i-VTEC ECO Elegance      2016      LPG & Benzin
# 19   C 180 BlueEFFICIENCY Avantgarde      2011            Benzin
#
#           Vites Tipi:         Motor Hacmi:       Motor Gücü:      Kilometre:  \
# 0              Düz              1248 cc             95 hp       67.314 km
# 1    Yarı Otomatik      1401 - 1600 cm3      151 - 175 HP      134.000 km
# 2         Otomatik              1598 cc            136 hp       54.000 km
# 3              Düz              1248 cc             70 hp      200.500 km
# 4    Yarı Otomatik      1801 - 2000 cm3      176 - 200 HP      147.000 km
# 5              Düz              1422 cc             75 hp      130.000 km
# 6    Yarı Otomatik              1968 cc            140 hp      260.000 km
# 7              Düz      1401 - 1600 cm3      101 - 125 HP      182.000 km
# 8    Yarı Otomatik              1598 cc            105 hp      139.000 km
# 9    Yarı Otomatik              1596 cc            105 hp       31.000 km
# 10             Düz              1248 cc             95 hp       98.000 km
# 11   Yarı Otomatik              1461 cc             90 hp      120.000 km
# 12             Düz              1598 cc            115 hp       69.738 km
# 13        Otomatik              1592 cc            170 hp       91.500 km
# 14   Yarı Otomatik              1461 cc             90 hp       71.782 km
# 15             Düz              1581 cc             83 hp       99.000 km
# 16   Yarı Otomatik              1422 cc             90 hp      101.051 km
# 17        Otomatik              1598 cc            136 hp       58.000 km
# 18        Otomatik              1598 cc            125 hp      127.000 km
# 19   Yarı Otomatik      1401 - 1600 cm3      151 - 175 HP      134.000 km
#
#     Boya-değişen:           Takasa Uygun:        Kimden:  Takasa Uygun     \
# 0   Takasa Uygun:                     NaN            NaN          Kimden:
# 1   Takasa Uygun:                     NaN            NaN          Kimden:
# 2   Takasa Uygun:                     NaN            NaN          Kimden:
# 3   Belirtilmemiş   Takasa Uygun Değil      Galeriden                 NaN
# 4   Takasa Uygun:                     NaN            NaN              NaN
# 5   Takasa Uygun:                     NaN            NaN              NaN
# 6   Takasa Uygun:                     NaN            NaN              NaN
# 7   Takasa Uygun:                     NaN            NaN              NaN
# 8   Takasa Uygun:                     NaN            NaN              NaN
# 9   Takasa Uygun:                     NaN            NaN          Kimden:
# 10  Takasa Uygun:                     NaN            NaN          Kimden:
# 11  Takasa Uygun:                     NaN            NaN          Kimden:
# 12  Takasa Uygun:                     NaN            NaN          Kimden:
# 13  Takasa Uygun:                     NaN            NaN          Kimden:
# 14  Takasa Uygun:                     NaN            NaN          Kimden:
# 15  Belirtilmemiş   Takasa Uygun Değil      Galeriden                 NaN
# 16  Takasa Uygun:                     NaN            NaN              NaN
# 17  Takasa Uygun:                     NaN            NaN          Kimden:
# 18  Takasa Uygun:                     NaN            NaN          Kimden:
# 19  Takasa Uygun:                     NaN            NaN          Kimden:
#
#     Takasa Uygun Değil
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                 Kimden:
# 5                 Kimden:
# 6                 Kimden:
# 7                 Kimden:
# 8                 Kimden:
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                Kimden:
# 17                    NaN
# 18                    NaN
# 19                    NaN

# %%
df.columns
# Out:
# Index(['İlan No:', 'İlan Tarihi:', 'Marka:', 'Seri:', 'Model:', 'Yıl:',
#        'Yakıt Tipi:', 'Vites Tipi:', 'Motor Hacmi:', 'Motor Gücü:',
#        'Kilometre:', 'Boya-değişen:', ' Takasa Uygun   '],
#       dtype='object')

# %%
df1=df1.iloc[:,1:11]
df1
# Out:
#           İlan Tarihi:               Marka:         Seri:  \
# 0    18 Aralık 2020      Mercedes - Benz             C
# 1    18 Aralık 2020                 Fiat         Albea
# 2    18 Aralık 2020                 Audi            A6
# 3    18 Aralık 2020           Volkswagen          Polo
# 4    18 Aralık 2020           Volkswagen        Passat
# 5    18 Aralık 2020           Volkswagen          Golf
# 6    18 Aralık 2020           Volkswagen          Golf
# 7    18 Aralık 2020                 Ford        Fiesta
# 8    18 Aralık 2020                 Fiat          Egea
# 9    18 Aralık 2020              Renault          Clio
# 10   18 Aralık 2020                 Opel         Astra
# 11   18 Aralık 2020                  BMW      5 Serisi
# 12   18 Aralık 2020              Renault          Clio
# 13                 NaN            TofaÅŸ        DoÄŸan
# 14   18 Aralık 2020           Volkswagen          Polo
# 15   18 Aralık 2020                 Opel         Astra
# 16   18 Aralık 2020                Honda         Civic
# 17   18 Aralık 2020      Mercedes - Benz             C
# 18   18 Aralık 2020                Honda         Civic
# 19   18 Aralık 2020               Toyota       Corolla
#
#                                  Model:      Yıl:       Yakıt Tipi:  \
# 0                C 200 d BlueTEC AMG      2016             Dizel
# 1     Sole 1.3 Multijet Dynamic Plus      2010             Dizel
# 2                   A6 Sedan 2.0 TDI      2012             Dizel
# 3                  1.4 TDi Trendline      2015             Dizel
# 4                   2.0 TDi Highline      2009             Dizel
# 5                      1.6 Primeline      2009      LPG & Benzin
# 6                1.6 TDi Comfortline      2011             Dizel
# 7                 1.6 Ti-VCT Trend X      2017      LPG & Benzin
# 8                  1.3 Multijet Easy      2016             Dizel
# 9                      1.5 dCi Touch      2016             Dizel
# 10                         1.6 Enjoy      2012      LPG & Benzin
# 11                      520i M Sport      2014            Benzin
# 12                     1.5 dCi Touch      2017             Dizel
# 13                               SLX          NaN               NaN
# 14               1.4 TDi Comfortline      2017             Dizel
# 15               1.6 CDTI Excellence      2016             Dizel
# 16           1.6 i-VTEC ECO Elegance      2016      LPG & Benzin
# 17   C 180 BlueEFFICIENCY Avantgarde      2011            Benzin
# 18                1.6 i-VTEC Premium      2011      LPG & Benzin
# 19                  1.4 D-4D Elegant      2011             Dizel
#
#           Vites Tipi:         Motor Hacmi:       Motor Gücü:      Kilometre:
# 0         Otomatik              1598 cc            136 hp       54.000 km
# 1              Düz              1248 cc             70 hp      200.500 km
# 2    Yarı Otomatik      1801 - 2000 cm3      176 - 200 HP      147.000 km
# 3              Düz              1422 cc             75 hp      130.000 km
# 4    Yarı Otomatik              1968 cc            140 hp      260.000 km
# 5              Düz      1401 - 1600 cm3      101 - 125 HP      182.000 km
# 6    Yarı Otomatik              1598 cc            105 hp      139.000 km
# 7    Yarı Otomatik              1596 cc            105 hp       31.000 km
# 8              Düz              1248 cc             95 hp       98.000 km
# 9    Yarı Otomatik              1461 cc             90 hp      120.000 km
# 10             Düz              1598 cc            115 hp       69.738 km
# 11        Otomatik              1592 cc            170 hp       91.500 km
# 12   Yarı Otomatik              1461 cc             90 hp       71.782 km
# 13             Düz              1581 cc             83 hp       99.000 km
# 14   Yarı Otomatik              1422 cc             90 hp      101.051 km
# 15        Otomatik              1598 cc            136 hp       58.000 km
# 16        Otomatik              1598 cc            125 hp      127.000 km
# 17   Yarı Otomatik      1401 - 1600 cm3      151 - 175 HP      134.000 km
# 18        Otomatik              1595 cc            125 hp      129.000 km
# 19             Düz              1364 cc             90 hp      165.000 km

# %%
pwd
# Out:
# 'C:\\Users\\mwolf\\Desktop'

# %%
df1.to_csv('arabam.csv')

# %%
df=pd.read_csv("arabam.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        İlan Tarihi:               Marka:        Seri:  \
# 0           0   08 Aralık 2020                 Fiat         Egea
# 1           1   08 Aralık 2020               Nissan        Micra
# 2           2   08 Aralık 2020                 Fiat         Egea
# 3           3   08 Aralık 2020              Renault      Fluence
# 4           4   08 Aralık 2020      Mercedes - Benz            B
#
#                   Model:  Yıl: Yakıt Tipi:        Vites Tipi:  \
# 0   1.3 Multijet Easy     2017    Dizel                Düz
# 1            1.2 Mood     2008   Benzin                Düz
# 2   1.3 Multijet Easy     2017    Dizel                Düz
# 3       1.5 dCi Touch     2016    Dizel      Yarı Otomatik
# 4         B 160 Sport     2010   Benzin      Yarı Otomatik
#
#           Motor Hacmi:      Motor Gücü:      Kilometre:
# 0           1248 cc            95 hp       86.900 km
# 1           1240 cc            65 hp      118.850 km
# 2           1248 cc            95 hp       98.420 km
# 3           1461 cc           110 hp      116.000 km
# 4   1401 - 1600 cm3      76 - 100 HP      127.500 km
